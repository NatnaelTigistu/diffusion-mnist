# %% [markdown]
# # DDPM on MNIST
# Run this in Colab with a GPU runtime: **Runtime -> Change runtime type -> T4 GPU**.
#
# This notebook clones the GitHub repo and runs the training/sampling scripts on Colab's free GPU.

# %%
# Replace with your repo URL after you push it to GitHub
REPO_URL = "https://github.com/<your-username>/diffusion-mnist.git"

# !git clone $REPO_URL
# %cd diffusion-mnist/src

# %%
# !pip install -q -r ../requirements.txt

# %%
import torch
print("GPU available:", torch.cuda.is_available())

# %%
# !python train.py --epochs 10 --batch_size 128

# %%
# !python sample.py --n 16

# %%
from IPython.display import Image
Image("../samples/grid.png")

# %% [markdown]
# ## Push results back to GitHub
# Only commit the small sample grid image, not the checkpoint (it's git-ignored by default).

# %%
# !git config user.email "you@example.com"
# !git config user.name "Your Name"
# !git add ../samples/grid.png
# !git commit -m "Add generated samples from Colab training run"
# Pushing from Colab needs a GitHub Personal Access Token as the password:
# !git push https://<your-username>:<YOUR_GITHUB_TOKEN>@github.com/<your-username>/diffusion-mnist.git
